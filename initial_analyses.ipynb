# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df = pd.read_csv('./data/U.S._Chronic_Disease_Indicators__CDI_.csv', index_col=0)
df
# Out:
# C:\Users\LARRY\AppData\Local\Temp\ipykernel_15876\1291510451.py:1: DtypeWarning: Columns (7,19,20,21,22,26,27,30,31,32,33) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('./data/U.S._Chronic_Disease_Indicators__CDI_.csv', index_col=0)
#            YearEnd LocationAbbr          LocationDesc DataSource  \
# YearStart
# 2013          2013           CA            California      YRBSS
# 2013          2013           CO              Colorado      YRBSS
# 2013          2013           CT           Connecticut      YRBSS
# 2013          2013           DC  District of Columbia      YRBSS
# 2013          2013           DE              Delaware      YRBSS
# ...            ...          ...                   ...        ...
# 2012          2012           WI             Wisconsin      BRFSS
# 2012          2012           WY               Wyoming      BRFSS
# 2012          2012           GU                  Guam      BRFSS
# ...

# %%
df.dtypes
# Out:
# YearEnd                        int64
# LocationAbbr                  object
# LocationDesc                  object
# DataSource                    object
# Topic                         object
# Question                      object
# Response                      object
# DataValueUnit                 object
# DataValueTypeID               object
# DataValueType                 object
# DataValue                     object
# DataValueAlt                 float64
# DataValueFootnoteSymbol       object
# DatavalueFootnote             object
# LowConfidenceLimit           float64
# HighConfidenceLimit          float64
# StratificationCategory1       object
# Stratification1               object
# StratificationCategory2       object
# Stratification2               object
# StratificationCategory3       object
# Stratification3               object
# GeoLocation                   object
# TopicID                       object
# QuestionID                    object
# ...

# %%
for col in df.columns:
    print(f'unique values of column {col}: {df[col].unique()}')
# Out:
# unique values of column YearEnd: [2013 2011 2012 2014 2010 2008 2001 2007]
# unique values of column LocationAbbr: ['CA' 'CO' 'CT' 'DC' 'DE' 'FL' 'GA' 'GU' 'HI' 'IA' 'ID' 'IL' 'IN' 'KS'
#  'KY' 'LA' 'MA' 'MD' 'ME' 'MI' 'MN' 'MO' 'MS' 'MT' 'NC' 'ND' 'NE' 'NH'
#  'NJ' 'NM' 'NV' 'NY' 'OH' 'OK' 'OR' 'PA' 'PR' 'RI' 'SC' 'SD' 'TN' 'TX'
#  'US' 'UT' 'VA' 'VI' 'VT' 'WA' 'WI' 'WV' 'WY' 'AK' 'AL' 'AR' 'AZ']
# unique values of column LocationDesc: ['California' 'Colorado' 'Connecticut' 'District of Columbia' 'Delaware'
#  'Florida' 'Georgia' 'Guam' 'Hawaii' 'Iowa' 'Idaho' 'Illinois' 'Indiana'
#  'Kansas' 'Kentucky' 'Louisiana' 'Massachusetts' 'Maryland' 'Maine'
#  'Michigan' 'Minnesota' 'Missouri' 'Mississippi' 'Montana'
#  'North Carolina' 'North Dakota' 'Nebraska' 'New Hampshire' 'New Jersey'
#  'New Mexico' 'Nevada' 'New York' 'Ohio' 'Oklahoma' 'Oregon'
#  'Pennsylvania' 'Puerto Rico' 'Rhode Island' 'South Carolina'
#  'South Dakota' 'Tennessee' 'Texas' 'United States' 'Utah' 'Virginia'
# ...

# %% [markdown]
# # It seems that the only columns with predominantly null values are columns Response, StratificationCategory2, Stratification2, StratificationCategory3, Stratification3, ResponseID, StratificationCategoryID2, StratificationID2, StratificationCategoryID3, StratificationID3
#
# maybe delete these columns instead

# %%
df.drop(columns=["Response",
    "StratificationCategory2",
    "Stratification2",
    "StratificationCategory3",
    "Stratification3",
    "ResponseID",
    "StratificationCategoryID2",
    "StratificationID2",
    "StratificationCategoryID3",
    "StratificationID3"], inplace=True)

# %%
df
# Out:
#            YearEnd LocationAbbr          LocationDesc DataSource  \
# YearStart
# 2013          2013           CA            California      YRBSS
# 2013          2013           CO              Colorado      YRBSS
# 2013          2013           CT           Connecticut      YRBSS
# 2013          2013           DC  District of Columbia      YRBSS
# 2013          2013           DE              Delaware      YRBSS
# ...            ...          ...                   ...        ...
# 2012          2012           WI             Wisconsin      BRFSS
# 2012          2012           WY               Wyoming      BRFSS
# 2012          2012           GU                  Guam      BRFSS
# 2012          2012           PR           Puerto Rico      BRFSS
# 2012          2012           VI        Virgin Islands      BRFSS
#
#                   Topic                                           Question  \
# YearStart
# 2013            Alcohol                            Alcohol use among youth
# ...

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#         YearStart  YearEnd LocationAbbr          LocationDesc DataSource  \
# 0            2013     2013           CA            California      YRBSS
# 1            2013     2013           CO              Colorado      YRBSS
# 2            2013     2013           CT           Connecticut      YRBSS
# 3            2013     2013           DC  District of Columbia      YRBSS
# 4            2013     2013           DE              Delaware      YRBSS
# ...           ...      ...          ...                   ...        ...
# 237956       2012     2012           WI             Wisconsin      BRFSS
# 237957       2012     2012           WY               Wyoming      BRFSS
# 237958       2012     2012           GU                  Guam      BRFSS
# 237959       2012     2012           PR           Puerto Rico      BRFSS
# 237960       2012     2012           VI        Virgin Islands      BRFSS
#
#                Topic                                           Question  \
# ...

# %%
df.dtypes
# Out:
# YearStart                      int64
# YearEnd                        int64
# LocationAbbr                  object
# LocationDesc                  object
# DataSource                    object
# Topic                         object
# Question                      object
# DataValueUnit                 object
# DataValueTypeID               object
# DataValueType                 object
# DataValue                     object
# DataValueAlt                 float64
# DataValueFootnoteSymbol       object
# DatavalueFootnote             object
# LowConfidenceLimit           float64
# HighConfidenceLimit          float64
# StratificationCategory1       object
# Stratification1               object
# GeoLocation                   object
# TopicID                       object
# QuestionID                    object
# LocationID                    object
# StratificationCategoryID1     object
# StratificationID1             object
# dtype: object

# %%
for col in df.columns:
    print(f'unique values of column {col}: {df[col].unique()}')
# Out:
# unique values of column YearStart: [2013 2011 2012 2014 2010 2008 2009 2001 2007]
# unique values of column YearEnd: [2013 2011 2012 2014 2010 2008 2001 2007]
# unique values of column LocationAbbr: ['CA' 'CO' 'CT' 'DC' 'DE' 'FL' 'GA' 'GU' 'HI' 'IA' 'ID' 'IL' 'IN' 'KS'
#  'KY' 'LA' 'MA' 'MD' 'ME' 'MI' 'MN' 'MO' 'MS' 'MT' 'NC' 'ND' 'NE' 'NH'
#  'NJ' 'NM' 'NV' 'NY' 'OH' 'OK' 'OR' 'PA' 'PR' 'RI' 'SC' 'SD' 'TN' 'TX'
#  'US' 'UT' 'VA' 'VI' 'VT' 'WA' 'WI' 'WV' 'WY' 'AK' 'AL' 'AR' 'AZ']
# unique values of column LocationDesc: ['California' 'Colorado' 'Connecticut' 'District of Columbia' 'Delaware'
#  'Florida' 'Georgia' 'Guam' 'Hawaii' 'Iowa' 'Idaho' 'Illinois' 'Indiana'
#  'Kansas' 'Kentucky' 'Louisiana' 'Massachusetts' 'Maryland' 'Maine'
#  'Michigan' 'Minnesota' 'Missouri' 'Mississippi' 'Montana'
#  'North Carolina' 'North Dakota' 'Nebraska' 'New Hampshire' 'New Jersey'
#  'New Mexico' 'Nevada' 'New York' 'Ohio' 'Oklahoma' 'Oregon'
# ...

# %%
df.columns
# Out:
# Index(['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'DataSource',
#        'Topic', 'Question', 'DataValueUnit', 'DataValueTypeID',
#        'DataValueType', 'DataValue', 'DataValueAlt', 'DataValueFootnoteSymbol',
#        'DatavalueFootnote', 'LowConfidenceLimit', 'HighConfidenceLimit',
#        'StratificationCategory1', 'Stratification1', 'GeoLocation', 'TopicID',
#        'QuestionID', 'LocationID', 'StratificationCategoryID1',
#        'StratificationID1'],
#       dtype='object')

# %% [markdown]
# # add id column to dataframe

# %%
df.reset_index(inplace=True)

# %%
df.rename(columns={'index': 'ID', 'DatavalueFootnote': 'DataValueFootnote'}, inplace=True)

# %%
df['ID'] = df['ID'].apply(lambda id: id + 1)

# %%
df
# Out:
#             ID  YearStart  YearEnd LocationAbbr          LocationDesc  \
# 0            1       2013     2013           CA            California
# 1            2       2013     2013           CO              Colorado
# 2            3       2013     2013           CT           Connecticut
# 3            4       2013     2013           DC  District of Columbia
# 4            5       2013     2013           DE              Delaware
# ...        ...        ...      ...          ...                   ...
# 237956  237957       2012     2012           WI             Wisconsin
# 237957  237958       2012     2012           WY               Wyoming
# 237958  237959       2012     2012           GU                  Guam
# 237959  237960       2012     2012           PR           Puerto Rico
# 237960  237961       2012     2012           VI        Virgin Islands
#
#        DataSource         Topic  \
# 0           YRBSS       Alcohol
# 1           YRBSS       Alcohol
# ...

# %% [markdown]
# # With the new dataframe we can import this to pgadmin4 using sqlalchemy and psycopg2

# %%
import psycopg2 
import pandas as pd 
from sqlalchemy import create_engine

# %%
user = 'postgres'
password = '0824'
host = 'localhost'
database = 'health_analytics_db'

# %%
conn_str = f'postgresql://{user}:{password}@{host}/{database}'
conn_str
# Out:
# 'postgresql://postgres:0824@localhost/health_analytics_db'

# %%
db = create_engine(conn_str)
conn = db.connect()

# %%
db
# Out:
# Engine(postgresql://postgres:***@localhost/health_analytics_db)

# %%
conn

# %%
df.to_sql(
    # name of sql table to be created in database
    name='ChronicDisease', 

    # 
    con=conn, 
    if_exists='replace', 

    # Write DataFrame index as a column. Uses 'index_label' as the column name in the table.
    # but since we already created an ID column there is no need
    index=False,
    )
# Out:
# 961

# %%
conn = psycopg2.connect(conn_str)
conn.autocommit = True
cursor = conn.cursor()

# %%
conn
# Out:
# <connection object at 0x000001FC1525BBC0; dsn: 'user=postgres password=xxx dbname=health_analytics_db host=localhost', closed: 0>

# %%
cursor
# Out:
# <cursor object at 0x000001FC8C5E2420; closed: 0>

# %% [markdown]
# # Alter imported table such that ID column is the primary key

# %%
query = '''
    ALTER TABLE "ChronicDisease" ADD PRIMARY KEY ("ID");
'''
cursor.execute(query)

# %% [markdown]
# # From here do any query you want

# %%
query = '''
    SELECT * FROM "ChronicDisease"; 
'''
cursor.execute(query)

# %%
data = cursor.fetchall()

# %%
for row in data[:10]:
    print(row)
# Out:
# (1, 2013, 2013, 'CA', 'California', 'YRBSS', 'Alcohol', 'Alcohol use among youth', '%', 'CrdPrev', 'Crude Prevalence', None, None, '-', 'No data available', None, None, 'Overall', 'Overall', '(37.63864012300047, -120.99999953799971)', 'ALC', 'ALC1_1', '6', 'OVERALL', 'OVR')
# (2, 2013, 2013, 'CO', 'Colorado', 'YRBSS', 'Alcohol', 'Alcohol use among youth', '%', 'CrdPrev', 'Crude Prevalence', None, None, '-', 'No data available', None, None, 'Overall', 'Overall', '(38.843840757000464, -106.13361092099967)', 'ALC', 'ALC1_1', '8', 'OVERALL', 'OVR')
# (3, 2013, 2013, 'CT', 'Connecticut', 'YRBSS', 'Alcohol', 'Alcohol use among youth', '%', 'CrdPrev', 'Crude Prevalence', '36.7', 36.7, None, None, 32.7, 41.0, 'Overall', 'Overall', '(41.56266102000046, -72.64984095199964)', 'ALC', 'ALC1_1', '9', 'OVERALL', 'OVR')
# ...

# %%
query = '''
    SELECT "ID" FROM "ChronicDisease";
'''
cursor.execute(query)
